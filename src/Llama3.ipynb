# %%
import pandas as pd
from fun import *
from common import generate_mapper
from groq import Groq
from dotenv import load_dotenv
import os
import json

# %% [markdown]
# # Data

# %%
df = pd.read_csv("../data/translations.csv")
df.head()
# Out:
#       lp                                                src  \
# 0  en-zh  Police said in a statement at the time that th...
# 1  en-zh  Trump will likely veto the resolution, the six...
# 2  en-zh  The man arrived at work about 9.30am after fai...
# 3  en-zh      Are hopes for a nuclear-free world realistic?
# 4  en-zh  The California attorney general's office in Ma...
#
#                                                   mt  \
# 0  警方在当时的一份声明中表示，他们决定以“沉重的心情”结束对 Jacsun 的搜索，但指出他们...
# 1  特 朗 普 可 能 会 否 决 该 决 议 ， 这 是 他 第 六 次 以 总 统 身 份 ...
# 2                    该名男子未能回复同事的几条短信和电话，于上午9.30左右上班。
# 3                                  对一个无核世界的希望是现实的吗 ？
# 4  3月,加利福尼亚总检察长办公室在经过近一年的调查后拒绝提出州刑事指控,当时,总检察长Xavi...
#
#                                                  ref     score        raw  \
# 0  警方在当时的一份声明中表示，他们在决定结束对杰森的搜寻时，是怀着“沉重的心情”的，并指出他们...  0.238989  80.500000
# 1  特朗普很可能行使总统否决权，这将是他成为总统以来第6次否决国会立法。他早在三月已动用否决权，...  0.487842  81.166667
# 2    该男子大约在上午 9:30 到达工作单位，在此之前，他未能回复同事发来的几条信息和打来的电话。  0.469850  80.500000
# 3                                    实现无核化世界的希望是否现实？  0.626218  81.000000
# 4  3 月，加州总检察长办公室在完成了近一年的案件调查后，拒绝对两名警察提起加州刑事起诉。总检察... -0.207602  59.000000
#
#    annotators domain  year  l1  l2
# 0           4   news  2020  en  zh
# 1           6   news  2020  en  zh
# 2           4   news  2020  en  zh
# 3           4   news  2020  en  zh
# 4           4   news  2020  en  zh

# %%
with open("../data/prompts/PROMPT4.txt", 'r') as f:
    prompt_template = f.read()

print(prompt_template)
# Out:
# Please evaluate the quality of the translation from [ORIGINAL LANGUAGE] to [TRANSLATED LANGUAGE] based on accuracy, fluency, and coherence:
# Provide a score from 0 to 100 to indicate the overall quality of the translation.

# %%
language_mapper = {
    'en': 'English',
    'fi': 'Finnish',
    'de': 'German',
    'hi': 'Hindi',
    'xh': 'Xhosa',
    'zh': 'Chinese',
    'cs': 'Czech',
    'fr': 'French',
    'bn': 'Bengali',
    'zu': 'Zulu'
}

# %%
df['l1'] = df['l1'].map(language_mapper)
df['l2'] = df['l2'].map(language_mapper)

# %%
def get_conversation_groq(src_language: str, trg_language: str, src_sentence: str, trg_sentence: str) -> str:
    messages = [
        {
            "role": "system",
            "content": f"""Please evaluate the quality of the translation from {src_language} to {trg_language} based on accuracy, fluency, and coherence: \n Provide a score from 0 to 100 to indicate the overall quality of the translation. Provide only the score, nothing else."""
        },
        {
            "role": "user",
            "content": f'Original sentence: "{src_sentence}" \n Translated sentence: "{trg_sentence}"'
        },
    ]
    return messages

# %%
df['message'] = df.apply(lambda x: get_conversation_groq(x['l1'], x['l2'], x['src'], x['mt']), axis=1)

# %%
df.iloc[0].message
# Out:
# [{'role': 'system',
#   'content': 'Please evaluate the quality of the translation from English to Chinese based on accuracy, fluency, and coherence: \n Provide a score from 0 to 100 to indicate the overall quality of the translation. Provide only the score, nothing else.'},
#  {'role': 'user',
#   'content': 'Original sentence: "Police said in a statement at the time that they made the decision to end the search for Jacsun with a "heavy heart," but noted they couldn\'t pinpoint a location in the landfill "to a point that would make continuing the search reasonable."" \n Translated sentence: "警方在当时的一份声明中表示，他们决定以“沉重的心情”结束对 Jacsun 的搜索，但指出他们无法确定垃圾填埋场的位置，“以至于继续搜索是合理的”。"'}]

# %% [markdown]
# # API calls

# %%
load_dotenv()
# Out:
# True

# %%
client = Groq()

# %%
input_data = df['message'].to_list()

# %%
chat_completion = client.chat.completions.create(
                messages=input_data[i],
                model="llama3-70b-8192",
                temperature=0.5,
                max_tokens=1024,
                top_p=1,
                stop=None,
                stream=False,
            )

# %%
input_data[0]
# Out:
# [{'role': 'system',
#   'content': 'Please evaluate the quality of the translation from English to Chinese based on accuracy, fluency, and coherence: \n Provide a score from 0 to 100 to indicate the overall quality of the translation. Provide only the score, nothing else.'},
#  {'role': 'user',
#   'content': 'Original sentence: "Police said in a statement at the time that they made the decision to end the search for Jacsun with a "heavy heart," but noted they couldn\'t pinpoint a location in the landfill "to a point that would make continuing the search reasonable."" \n Translated sentence: "警方在当时的一份声明中表示，他们决定以“沉重的心情”结束对 Jacsun 的搜索，但指出他们无法确定垃圾填埋场的位置，“以至于继续搜索是合理的”。"'}]

# %%
last_idx = 1500
max_rows = 2401
outfile = f'../data/llama_3/{last_idx}_starting_row.json'

with open(outfile, 'w') as output_file:
    output_file.write('[')
    for i in range(last_idx, len(input_data[:max_rows])):
        try:
            sample = input_data[i]
            chat_completion = client.chat.completions.create(
                messages=input_data[i],
                model="llama3-70b-8192",
                temperature=0.5,
                max_tokens=1024,
                top_p=1,
                stop=None,
                stream=False,
            )
            answer = chat_completion.choices[0].message.content

            output_sample = {'sentence': sample[-1]['content'],'score': answer, 'id':i}
            
            output_file.write(json.dumps(output_sample))

            if i != (max_rows-1):
                output_file.write(',')
        except:
            print('next start by:')
            print(i + 1)
            break
    output_file.write(']')

# %%
with open(outfile) as file:
    content = json.load(file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[105], line 2
#       1 with open(outfile) as file:
# ----> 2     content = json.load(file)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 650133 (char 650132)

# %%
content
# Out:
# [{'sentence': 'Original sentence: "It\'s not a big meeting, it\'s not a Royal Ascot - it\'s a mundane Friday night with 20,000 people." \n Translated sentence: "这不是一个大型的会议，它不是皇家 Ascot -它是一个普通的星期五晚上，有20，000人。"',
#   'score': '85',
#   'id': 250},
#  {'sentence': 'Original sentence: "Still there has been a surge in support -- more than 75 House members in about three days -- of launching such an inquiry as part of the fallout from Trump\'s July 25 call with Ukrainian President Volodymyr Zelensky where he discussed former Vice President Joe Biden. There is no evidence of wrongdoing by Biden." \n Translated sentence: "尽管如此，在特朗普7月25日与乌克兰总统弗拉基米尔*泽伦斯基（Volodymyr Zelensky）的电话会议中，他讨论了前副总统乔*拜登（Joe Biden）的后果，仍然有一个激增的支持-在大约三天内超过75众议院成员。 没有证据表明拜登有不法行为。"',
#   'score': '92',
#   'id': 251},
#  {'sentence': 'Original sentence: "Twarock said the new blueprints also provide "a new perspective on viral evolution, suggesting novel routes in which larger and more complex viruses may have evolved from simple ones at evolutionary timescales."" \n Translated sentence: "特瓦洛克表示，新蓝图还提供了“病毒进化的新视角，提出了新的途径，在这些途径中，更大、更复杂的病毒可能从进化时间尺度上的简单病毒进化而来。”"',
#   'score': '92',
#   'id': 252},
#  {'sentence': 'Original sentence: "Holding the knife in his right hand, he tied her hands and feet with cable ties before lashing her to the tree and abusing her for almost an hour. After he cut her loose, the girl ran crying hysterically to school." \n Translated sentence: "他右手拿着刀，用缆绳绑住她的手脚，然后将她鞭打在树上，虐待了她近一个小时，在他将她割开后，女孩歇斯底里地哭着跑到学校。"',
#   'score': '85',
#   'id': 253},
#  {'sentence': 'Original sentence: "Fiji started magnificently, bouncing off GB tackles for fun." \n Translated sentence: "斐济开始了壮观地，弹起乐趣的GB滑车。"',
#   'score': '60',
#   'id': 254},
#  {'sentence': 'Original sentence: "The birthday-suited shopper\'s identity remains unknown, though she appears to have been allowed to leave the premises after the impromptu peep show." \n Translated sentence: "这位适合生日的购物者的身份仍然不明，尽管她似乎在即兴窥视表演后被允许离开。"',
#   'score': '85',
#   'id': 255},
#  {'sentence': 'Original sentence: ""We share so many similar interests and values, and we know that this will stand us in great stead for the years ahead, full of love and happiness."" \n Translated sentence: "“我们有很多相似的兴趣和价值观，我们知道，这将使我们在未来的岁月里大有作为，充满爱和幸福。”"',
#   'score': '92',
#   'id': 256},
#  {'sentence': 'Original sentence: "Then again, they said the same about Severn Cullis-Suzuki in 1992. Long before Thunberg deadpanned to parliamentarians that "we probably don\'t even have a future any more," and netizens tore each other to shreds attacking and defending her, 12-year-old Cullis-Suzuki became known as the "The girl who silenced the world for five minutes" when she delivered a similar sermon before the UN Earth Summit in Rio de Janeiro." \n Translated sentence: "再说一次，他们在1992年对塞文·库里斯·铃木说了同样的话。在图恩伯格向国会议员僵持之前，“我们甚至可能再也没有未来了”。岁的库利斯·铃木（Cullis-Suzuki）在里约热内卢举行的联合国地球峰会上发表了类似的讲道时，被称为“沉默世界五分钟的女孩”。"',
#   'score': '85',
#   'id': 257},
#  {'sentence': 'Original sentence: "Gaynor\'s nomination to the post was expected. He will require a majority of the Senate to approve the nomination to take the job." \n Translated sentence: "盖纳被提名为该职位。 他将要求参议院的多数批准接受这份工作的提名。"',
#   'score': '85',
#   'id': 258},
#  {'sentence': 'Original sentence: "Police have approved a major rally in downtown Hong Kong on Saturday organized by the Civil Human Rights Front to mark the fifth anniversary of the start of the Umbrella Revolution, when protesters occupied key thoroughfares in the city for 79 days in 2014 to demand universal suffrage. That movement ended without any government concession." \n Translated sentence: "警方批准民间人权阵线(Civil Human Rights Front)周六在香港市中心举行大型集会，纪念“雨伞革命”(Umbrella Revolution)爆发五周年。2014年，“雨伞革命”(Umbrella Revolution)爆发，抗议者占领香港主要街道79天，要求普选。"',
#   'score': '92',
#   'id': 259},
#  {'sentence': 'Original sentence: ""Currently we are targeting young people 18 to 24 years. For the young people that\'s the age bracket we are looking at but of course any one above 18 and it\'s because we do not have evidence of children by the Constitution but as more evidence unfolds we are going to get there. For the men, we give the kit to the mother and they take it to the partner, key and priority populations such sex workers," Mr Geoffrey Tasi, the technical officer-in-charge of HIV testing services, said yesterday." \n Translated sentence: "“目前，我们的目标是18至24岁的年轻人。对于我们正在关注的年龄段的年轻人，当然也包括任何18岁以上的人，这是因为我们没有《宪法》规定的儿童证据，但随着更多证据的展开，我们将实现这一目标。对于男性，我们将工具包交给母亲，他们将工具包带给伴侣、关键和优先人群，比如性工作者，”杰弗里·塔西先生说。负责艾滋病毒检测服务的技术官员昨日表示。"',
#   'score': '92',
#   'id': 260},
#  {'sentence': 'Original sentence: ""Here you walk outside and it\'s like somebody put a heater on you. I guess that is why they are doing it at night."" \n Translated sentence: ""如果你走在外面,那就像有人把一个暖气放在你身上,我猜测这就是为什么他们在夜间做这件事。"',
#   'score': '85',
#   'id': 261},
#  {'sentence': 'Original sentence: "And they\'re determined to take back power by using any means necessary, you see the meanness, the nastiness." \n Translated sentence: "他们决心用任何必要的手段夺回权力，你看这是卑鄙的，是卑鄙的。"',
#   'score': '85',
#   'id': 262},
#  {'sentence': 'Original sentence: "The State Department didn\'t immediately respond to CNBC\'s request for comment." \n Translated sentence: "美国国务院没有立即回应CNBC的置评请求。"',
#   'score': '95',
#   'id': 263},
#  {'sentence': 'Original sentence: "Some of the first protests began in New Zealand, where Thunberg saidorganizers estimated 170,000 people marched across the country. There were also marches in cities in Italy, Finland, Nigeria, Austria and India, among other countries." \n Translated sentence: "最初的一些抗议活动始于新西兰，图恩伯格说组织者估计全国有17万人游行。在意大利，芬兰，尼日利亚，奥地利和印度等城市也有游行。"',
#   'score': '92',
#   'id': 264},
#  {'sentence': 'Original sentence: "Qandeel Baloch, who shot to fame for her social media photos, was strangled in July 2016." \n Translated sentence: "因社交媒体照片而一举成名的坎德尔·巴洛奇于2016年7月被勒死。"',
#   'score': '95',
#   'id': 265},
#  {'sentence': 'Original sentence: "According to Rouhani, European signatories of the 2015 nuclear deal urged him to meet with US President Donald Trump, promising that Washington would lift "all" sanctions in return." \n Translated sentence: "根据鲁哈尼的说法，2015年核协议的欧洲签署国敦促他会晤美国总统特朗普，承诺华盛顿将取消“所有”制裁作为回报。"',
#   'score': '95',
#   'id': 266},
#  {'sentence': 'Original sentence: "It comes after a divisive week in Westminster following the return of Parliament." \n Translated sentence: "它是在议会返回后在威斯敏斯特发生分裂的一周后发生的。"',
#   'score': '85',
#   'id': 267},
#  {'sentence': 'Original sentence: "Peloton reported rapid top-line growth of 110% during the fiscal year that ended June 30. But the company also showed negative operating leverage, with operating expenses surging 147% over the prior year." \n Translated sentence: "Peloton报告在30. 年6月结束的财政年度快速顶级增长110但公司也显示出负运营杠杆, 运营开支比上一年猛增147"',
#   'score': '85',
#   'id': 268},
#  {'sentence': 'Original sentence: "We took their concerns to Dean Baquet, The Times\'s executive editor, who responded to them in a discussion with the Reader Center:" \n Translated sentence: "我们把他们的担忧转达给了《纽约时报》执行编辑迪恩*巴奎特(Dean Baquet)，后者在与读者中心的讨论中回应了他们:"',
#   'score': '95',
#   'id': 269},
#  {'sentence': 'Original sentence: "Williams was also fined a total of $17,000 last year after she defended herself against an umpire at the U.S. Open who accused her of illegally communicating with her coach during a match." \n Translated sentence: "去年，威廉姆斯还被罚款了17,000美元，因为她为自己辩护，反对美国公开赛的裁判，他指责她在比赛期间与教练非法沟通。"',
#   'score': '85',
#   'id': 270},
#  {'sentence': 'Original sentence: ""Sounding more and more like the so-called whistle-blower isn\'t a whistle-blower at all," he tweeted. "In addition, all second-hand information that proved to be so inaccurate that there may not have been somebody else, a leaker or spy, feeding it to him or her? A partisan operative?"" \n Translated sentence: "“听起来越来越像所谓的告密者根本不是告密者，”他在Twitter上说，“此外，所有二手信息都被证明是如此不准确，以至于可能没有其他人、泄密者或间谍提供给他或她？一个党派特工？”"',
#   'score': '95',
#   'id': 271},
#  {'sentence': 'Original sentence: "The aviation regulator said it has brought back over 40% of the total number of passengers in the largest peacetime repatriation \'Operation Matterhorn\' launched on Monday." \n Translated sentence: "航 空 监 管 机 构 表 示 ， 在 周 一 启 动 的 和 平 时 期 最 大 规 模 的 遣 返 行 动 “ 马 特 霍 恩 行 动 ” 中 ， 他 们 已 经 带 回 了 超 过 40 % 的 乘 客 。"',
#   'score': '92',
#   'id': 272},
#  {'sentence': 'Original sentence: "Michael Schumacher\'s Manager with a Statement about his Condition" \n Translated sentence: "迈克尔·舒马赫的经纪人对他的状况发表了声明"',
#   'score': '95',
#   'id': 273},
#  {'sentence': 'Original sentence: "Iranian President Hassan Rouhani makes a speech during a ceremony in Tehran, Iran on January 10, 2019." \n Translated sentence: "伊朗总统哈桑·鲁哈尼在2019年1月10日于伊朗德黑兰举行的仪式上发言。"',
#   'score': '95',
#   'id': 274},
#  {'sentence': 'Original sentence: "In an exclusive interview with the Standard, former Cabinet minister Amber Rudd today accused Mr Johnson of deploying aggressive language that "does incite violence."" \n Translated sentence: "前 内 阁 部 长 安 柏 · 陆 克 文 今 天 在 接 受 《 标 准 报 》 独 家 采 访 时 指 责 约 翰 逊 使 用 了 “ 确 实 煽 动 暴 力 ” 的 攻 击 性 语 言 。"',
#   'score': '92',
#   'id': 275},
#  {'sentence': 'Original sentence: "A woman accused of shoplifting at a Walmart in Mexico City took drastic measures to prove her innocence, stripping stark naked in the middle of the supermarket as a stunned security guard looked on." \n Translated sentence: "一名被指控在墨西哥城沃尔玛商店行窃的妇女采取了严厉措施来证明自己的清白，在超市中央赤裸裸地脱光衣服，一名惊呆的保安在一旁看着。"',
#   'score': '95',
#   'id': 276},
#  {'sentence': 'Original sentence: "A Harris County jury found Ronald Haskell, 39, guilty in the July 2014 killings of six members of the Stay family: parents Stephen Stay and Katie Stay, and children Bryan, 13, Emily, 9, Rebecca, 7 and Zach, 4." \n Translated sentence: "哈里斯县陪审团裁定罗纳德·哈斯克尔, 39岁, 2014年7月杀害了2014名Stay家庭成员: 父母Stephen Stay和Katie Stay, 和儿童Bryan, 13岁, Emily, 9岁, Rebecca 7和扎克, 4."',
#   'score': '85',
#   'id': 277},
#  {'sentence': 'Original sentence: "Neumann Kaffee Gruppe (NKG), one of the world\'s largest traders, said glyphosate was one of a number of substances it monitored on the coffee it buys. Nestle buys some of its coffee beans from NKG. It was too early to say what consequences Nestle\'s tighter controls would have on NKG, a spokesperson said." \n Translated sentence: "全球最大的贸易商之一 Neumann Kaffee Gruppe (NKG) 表示 ， 草甘膦是它购买的咖啡中监测到的众多物质之一 ， 雀巢公司从 NKG 购买了部分咖啡豆 ， 现在就说雀巢公司对 NKG 实施更严格的控制会带来什么后果还为时过早。"',
#   'score': '92',
#   'id': 278},
#  {'sentence': 'Original sentence: ""They emit less energy, so they are fainter than the sun, and their surface temperature is rather cool, below 3800 (degrees) Kelvin (6,380 degrees Fahrenheit/3,527 Celsius) approximately. This is why the have a reddish color," Morales said." \n Translated sentence: "莫拉莱斯说：“它们散发出来的能量更少，因此比太阳还暗，表面温度也很凉，大约低于3800开氏度（6,380华氏度/ 3,527摄氏度）。这就是为什么它的颜色偏红的原因。” 。"',
#   'score': '95',
#   'id': 279},
#  {'sentence': 'Original sentence: ""We nicknamed him "Lucky" and I think the name applies," the officer said. "He\'s definitely one lucky dog."" \n Translated sentence: "“我们给他起了个绰号叫“ Lucky ”，我想这个名字也适用，”警官说，“他绝对是一只幸运的狗。”"',
#   'score': '95',
#   'id': 280},
#  {'sentence': 'Original sentence: "Facebook has begun hiding the number of "likes" for posts in Australia, it said today, a trial designed to ease social pressure that could be rolled out worldwide." \n Translated sentence: "Facebook今天表示，它已经开始隐藏澳大利亚帖子的"赞"数量，该试验旨在缓解可能在全球推出的社会压力。"',
#   'score': '92',
#   'id': 281},
#  {'sentence': 'Original sentence: "NHS Lanarkshire treated 912 people and NHS Ayrshire 439, both four-year highs." \n Translated sentence: "NHS拉纳克郡治疗了912人，NHS艾尔郡439人，这两者都是四年来的最高水平。"',
#   'score': '85',
#   'id': 282},
#  {'sentence': 'Original sentence: "After integrating the inspection twice, Ma Qi, the deputy head of Urumqi City Tourism Law Enforcement Detachment said that, "Safety first, norm second. No small matters for the travel vehicles. And people will be injured and killed in groups in case of any questions."" \n Translated sentence: "乌鲁木齐市旅游局支队副局长马琦将这次检查整合后说，“安全第一，规范二。对于旅游车辆来说，不小的事情。。。。。。任何问题上的人都会在团伙中受伤和杀害。“"',
#   'score': '85',
#   'id': 283},
#  {'sentence': 'Original sentence: "In August, the government compulsorily retired 22 CBIC officials. The Rule 56 (J) of Central Civil Services (Pension) Rules, 1972 provides for periodical review of the performance of government servants with a view to ascertain whether they should be retained in service or retired in public interest." \n Translated sentence: "今年8月，政府强制退休了22名CBIC官员。1972年《中央公务员（养恤金）规则》第56（J）条规定，定期审查政府公务员的业绩，以确定他们应留任还是为了公共利益退休。"',
#   'score': '95',
#   'id': 284},
#  {'sentence': 'Original sentence: "The capsid shell is what protects them, and as scientists discovered their structure, they proposed that capsids could have different sizes and hold different amounts of genome, and therefore could infect hosts differently." \n Translated sentence: "衣壳是保护它们的东西，当科学家发现它们的结构时，他们提出衣壳可以有不同的大小和不同数量的基因组，因此可以以不同的方式感染宿主。"',
#   'score': '92',
#   'id': 285},
#  {'sentence': 'Original sentence: "The world\'s largest coffee company said in a statement Friday that it had found glyphosate residues close to the maximum allowed in some deliveries of green coffee beans." \n Translated sentence: "这 家 全 球 最 大 的 咖 啡 公 司 周 五 在 一 份 声 明 中 表 示 ， 在 一 些 交 付 的 绿 色 咖 啡 豆 中 发 现 草 甘 膦 残 留 接 近 允 许 的 最 大 值 。"',
#   'score': '92',
#   'id': 286},
#  {'sentence': 'Original sentence: "Thunberg and the young people she has inspired say they will not stop their weekly classroom walkouts until they see a reduction in greenhouse gas emissions responsible for climate change." \n Translated sentence: "Thunberg 和她所激励的年轻人说 ， 他们不会停止每周的课堂罢工 ， 直到他们看到负责气候变化的温室气体排放减少。"',
#   'score': '92',
#   'id': 287},
#  {'sentence': 'Original sentence: "Scotland\'s Community Safety Minister pledged to "keep communities safe from irresponsible owners," with reviews to determine whether laws for out-of-control dogs need changing." \n Translated sentence: "苏格兰社区安全部长承诺“保护社区免受不负责任的主人的伤害”，并进行审查，以确定对失控狗的法律是否需要改变。"',
#   'score': '85',
#   'id': 288},
#  {'sentence': 'Original sentence: ""In this village, we provided medication and ultrasound-B service, while in another village, Qiu Jia Dian Zi Village of Hu Bu Town of Wulian County, free medical service was provided by the service team."" \n Translated sentence: "在这个村子里，我们提供了药品和高质量的服务，而在另一个村庄，胡安湖镇胡布镇的村庄，服务小组提供免费医疗服务。"',
#   'score': '85',
#   'id': 289},
#  {'sentence': 'Original sentence: "About 100,000 security personnel are to guard polling stations in the wake of Taliban threats." \n Translated sentence: "在塔利班受到威胁后，大约10万名安全人员将守卫投票站。"',
#   'score': '95',
#   'id': 290},
#  {'sentence': 'Original sentence: "In case of more severe disturbances, there are also fluctuations in the electricity grid. Satellites providing navigation information are also vulnerable." \n Translated sentence: "如果发生更严重的扰动,电网也会出现波动,提供导航信息的卫星也很脆弱。"',
#   'score': '92',
#   'id': 291},
#  {'sentence': 'Original sentence: "Francis addressed a Vatican conference that brought government envoys and Facebook and Google representatives together with philosophers, physicists and ethicists. A smattering of academics and Catholic bishops rounded out participants at "The Common Good in the Digital Age" conference." \n Translated sentence: "弗朗西斯在梵蒂冈的一次会议上发表了讲话，参加会议的有政府特使、脸书和谷歌的代表以及哲学家、物理学家和伦理学家。一些学者和天主教主教参加了“数字时代的共同利益”会议。"',
#   'score': '95',
#   'id': 292},
#  {'sentence': 'Original sentence: "What began as a test on Instagram in Canada was expanded to Australia, Brazil and several other major markets." \n Translated sentence: "在加拿大 ， 对 Instagram 的测试开始扩大到澳大利亚、巴西和其他几个主要市场。"',
#   'score': '95',
#   'id': 293},
#  {'sentence': 'Original sentence: "According to Minsheng Guancha, a Chinese human rights group, Cao was later able to see Wang\'s body and saw he was bleeding from his eyes, mouth, ears and nose and there were bruises on his face." \n Translated sentence: "据 中 国 人 权 组 织 民 生 观 察 称 ， 曹 国 后 来 看 到 了 王 的 尸 体 ， 看 到 他 的 眼 睛 、 嘴 巴 、 耳 朵 和 鼻 子 都 在 流 血 ， 脸 上 也 有 瘀 伤 。"',
#   'score': '95',
#   'id': 294},
#  {'sentence': 'Original sentence: "The United States said in May it had received numerous reports that appeared consistent with chemical exposure after an attack by the forces of Bashar al-Assad, the Syrian president, in northwestern Syria, but it had made no definitive conclusion as to whether they used chemical weapons." \n Translated sentence: "美国5月表示，在叙利亚总统巴沙尔·阿萨德（Bashar al-Assad）的部队在叙利亚西北部发动袭击后，美国收到了大量似乎与化学接触相符的报告，但没有就他们是否使用了化学武器做出明确结论。"',
#   'score': '95',
#   'id': 295},
#  {'sentence': 'Original sentence: "In a report issued Friday, Britain\'s National Audit Office said additional shipping capacity chartered by the U.K. for sending goods across the English Channel might not be operational until the end of November - one month after the Oct. 31 deadline for Britain to leave the European Union. Of the more than 12,300 medicines licensed in the U.K., about 7,000 arrive from or via the EU, mostly across the Channel." \n Translated sentence: "在周五发布的一份报告中，英国国家审计署表示，英国规定的通过英吉利海峡运送货物的额外运输能力可能要到11月底才能生效，这是10月31日英国离开欧盟最后期限的一个月。在英国获得许可的12,300多种药品中，大约有7,000种来自欧盟或通过欧盟（主要是通过海峡）到达。"',
#   'score': '95',
#   'id': 296},
#  {'sentence': 'Original sentence: "The report even suggests putting indelible ink on a person\'s fingers as they cast their ballot to prevent anyone being able to vote twice." \n Translated sentence: "该报告甚至建议将不褪色墨水对一个人的手指，因为他们投他们的票以防止任何人能够投票的两倍。"',
#   'score': '85',
#   'id': 297},
#  {'sentence': 'Original sentence: "Trump has denied there was any impropriety with the phone call. Friday, he denounced the complainant and again said the call with Zelensky was a "perfect conversation"" \n Translated sentence: "特朗普否认这个电话有任何不当行为。 星期五，他谴责申诉人，并再次表示与Zelensky的电话是一个"完美的对话""',
#   'score': '95',
#   'id': 298},
#  {'sentence': 'Original sentence: "In July, the committee\'s MSPs concluded current dog control legislation is not fit for purpose and called on the Scottish Government to undertake a comprehensive review of all dog-control laws." \n Translated sentence: "今年7月，该委员会的MSPs得出结论认为，现行的犬类管制立法不符合目的，并呼吁苏格兰政府对所有犬类管制法律进行全面审查。"',
#   'score': '95',
#   'id': 299},
#  {'sentence': 'Original sentence: "The latest firestorm comes as Mr. Trump has been trying to refocus his campaign on the economy amid declining poll numbers." \n Translated sentence: "Poslední fiasko přichází, jak se pan Trump snaží znovu zaměřit svou kampaň na ekonomiku uprostřed klesajících průzkumů veřejného mínění."',
#   'score': '92',
#   'id': 300},
#  {'sentence': 'Original sentence: "The programme which was held under the theme "Rabies: Vaccinate to eliminate" was organised by the Food and Agriculture Organisation (FAO) in collaboration with the Ministry of Agriculture Veterinary Service." \n Translated sentence: "Program, který se konal pod tématem ′′ Vzteklina: očkovat k odstranění organizovala Organizace pro výživu a zemědělství (FAO) ve spolupráci s Ministerstvem zemědělské veterinární služby."',
#   'score': '95',
#   'id': 301},
#  {'sentence': 'Original sentence: "Astronomers used a worldwide network of telescopes to detect the phenomenon before looking at TESS, whose permanent viewing zones designed to find distant planets, caught the beginning of the violent event." \n Translated sentence: "Astronomové využili celosvětovou síť dalekohledů k odhalení fenoménu před tím, než se podívali na TESS, jehož trvalé prohlížecí zóny navržené k nalezení vzdálených planet, zachytily začátek násilné události."',
#   'score': '95',
#   'id': 302},
#  {'sentence': 'Original sentence: "They have considered my appeal, and I have won." \n Translated sentence: "Uvažovali o mém odvolání a vyhrál jsem."',
#   'score': '95',
#   'id': 303},
#  {'sentence': 'Original sentence: "This will help the present generation to know about the man, who had waged a war against women oppression and propagated widow remarriage, he said." \n Translated sentence: "To pomůže současné generace, vědět o muže, kteří vedli válku proti útlaku žen a množí vdova manželství, řekl."',
#   'score': '80',
#   'id': 304},
#  {'sentence': 'Original sentence: "The four-time All-Pro wide receiver wrote on Twitter on Thursday: "I\'m still the best why stop now." He followed with the suggestion that the game needs him." \n Translated sentence: "Čtyřnásobný hráč All-Pro ve čtvrtek na Twitter napsal: „Pořád jsem ten nejlepší, proč teď přestat.“ Následoval ho s náznakem, že ho hra potřebuje."',
#   'score': '96',
#   'id': 305},
#  {'sentence': 'Original sentence: "Medal hopefuls must go farther, faster, up and over, in their quest for gold, sometimes to the finish, other times back and forth up and down the court." \n Translated sentence: "Medaile doufá, že se budou pohybovat dál, rychleji, nahoru a znovu, v jejich hledání zlata, někdy až do konce, jindy zase a zpět a zpět u dvora."',
#   'score': '85',
#   'id': 306},
#  {'sentence': 'Original sentence: "You would do absolutely anything to get your child out of the danger zone, and this family did everything in their power to get their daughter back home." \n Translated sentence: "Udělali byste naprosto cokoliv, abyste své dítě z nebezpečné zóny dostali, a tato rodina udělala vše, co je v jejich silách, aby svou dceru vrátila zpět domů."',
#   'score': '96',
#   'id': 307},
#  {'sentence': 'Original sentence: "Military suicides surged this year to a record high among active duty troops, continuing a deadly trend that Pentagon officials say is frustrating and they are struggling to counter." \n Translated sentence: "Vojenské sebevraždy se letos vyšplhaly na rekordní úroveň mezi vojáky v aktivní službě a pokračují ve smrtícím trendu, který je podle představitelů Pentagonu frustrující a snaží se mu čelit."',
#   'score': '95',
#   'id': 308},
#  {'sentence': 'Original sentence: "PM Modi Tweets Tribute To Jacques Chirac, Calls Him True Global Statesman, Friend Of India" \n Translated sentence: "PM Modi Tweets hold Jacques Chirac, říká mu pravý globální státník, přítel Indie"',
#   'score': '85',
#   'id': 309},
#  {'sentence': 'Original sentence: "A 28-year-old chef who had recently moved to San Francisco was found dead in the stairwell of a local mall this week." \n Translated sentence: "28 - letý kuchař, který nedávno přestěhoval do San Francisca, byl nalezen mrtev na schodišti místní místní místní nákupní středisko."',
#   'score': '85',
#   'id': 310},
#  {'sentence': 'Original sentence: "China on Friday said it has not provoked a "single war or conflict" or "invaded a single square" of foreign land, skirting any reference to the 1962 war with India." \n Translated sentence: "Čína v pátek prohlásila, že nevyvolala „jedinou válku nebo konflikt“ ani „nenapadla jediný čtverec“ cizí země, čímž obešla jakoukoli zmínku o válce s Indií z roku 1962."',
#   'score': '96',
#   'id': 311},
#  {'sentence': 'Original sentence: "Parliament has met for the second day since the Supreme Court ruled its suspension as unlawful." \n Translated sentence: "Parlament se sešel již druhý den od doby, kdy Nejvyšší soud rozhodl, že je pozastavení pozastavení jako protiprávní."',
#   'score': '85',
#   'id': 312},
#  {'sentence': 'Original sentence: ""This consultation seeks views on improvements on how the Control of Dogs Act 2010 can operate across Scotland, and next year we will take a wider look at all dog control legislation to assess whether changes are needed." \n Translated sentence: "„Tato konzultace hledá názory na zlepšení toho, jak může zákon o kontrole psů 2010 fungovat ve Skotsku, a příští rok se podrobněji podíváme na všechny právní předpisy týkající se kontroly psů, abychom zhodnotili, zda jsou nutné změny."',
#   'score': '92',
#   'id': 313},
#  {'sentence': 'Original sentence: "\'It is particularly satisfying that Ruby has produced a female calf - these are vital for the development of the breeding programme and Stella will eventually move to another collection to hopefully become a successful mother herself.\'" \n Translated sentence: "„Obzvláště uspokojující je, že Ruby porodila samičku – ta je životně důležitá pro rozvoj chovného programu a Stella se nakonec přesune do jiné sbírky, aby se snad sama stala úspěšnou matkou.“"',
#   'score': '95',
#   'id': 314},
#  {'sentence': 'Original sentence: "In this situation, the Ukrainian regime desperately needs to attract attention to its country to justify requests for further financial assistance in an attempt to improve their reputation with Ukrainian voters." \n Translated sentence: "V této situaci ukrajinský režim zoufale potřebuje přilákat pozornost své země, aby ospravedlnil žádosti o další finanční pomoc ve snaze zlepšit svou pověst ukrajinských voličů."',
#   'score': '95',
#   'id': 315},
#  {'sentence': 'Original sentence: "A string of scandals has plagued the force, covering Hartlepool, Redcar and Cleveland, Stockton and Middlesbrough in the north east of England." \n Translated sentence: "Síly sužuje řada skandálů, které se týkají Hartlepoolu, Redcaru a Clevelandu, Stocktonu a Middlesbrough na severovýchodě Anglie."',
#   'score': '95',
#   'id': 316},
#  {'sentence': 'Original sentence: "The agency has been without a Senate-confirmed administrator since March, when Brock Long left the post. Long resigned after the Department of Homeland Security, under which FEMA falls, concluded Long had inappropriately used government vehicles to commute between Washington and his home in North Carolina." \n Translated sentence: "Agentura byla od března bez potvrzeného správce, kdy Brock Long opustil místo. Dlouhé rezignované po oddělení vlasti bezpečnosti, pod kterým FEMA padá, uzavřela Dlouho nevhodně používala vládní vozidla dojíždět mezi Washingtonem a jeho domovem v Severní Karolíně."',
#   'score': '85',
#   'id': 317},
#  {'sentence': 'Original sentence: "Mother Ruby joined the wildlife park in 2009 alongside another female called Nancy in the hope that one would produce the park\'s first ever calf with Monty." \n Translated sentence: "Matka Ruby se připojila k parku divoké zvěře v roce 2009 po boku další samice jménem Nancy v naději, že jedna z nich porodí v parku vůbec první mládě s Montym."',
#   'score': '95',
#   'id': 318},
#  {'sentence': 'Original sentence: "The White House lawyers" directive to move the transcript has been characterized by top Democrats as a "cover-up."" \n Translated sentence: "Směrnice právníků Bílého domu k přesunutí přepisu byla nejvyššími demokraty charakterizována jako „zastírací manévr“."',
#   'score': '96',
#   'id': 319},
#  {'sentence': 'Original sentence: "Just when I was ready to return to preparation in Příbram last year, I started having problems with my heart." \n Translated sentence: "Zrovna když jsem byl připraven na přípravný návrat do přípravného příbram, začal jsem mít problémy se srdcem."',
#   'score': '60',
#   'id': 320},
#  {'sentence': 'Original sentence: "Dr Kaluwa noted that 99 per cent of zoonotic disease like rabies was transmitted from dogs to humans, adding that One Health approach to controlling and ultimately eliminating human rabies was expedient." \n Translated sentence: "Dr. Kaluwa poznamenal, že 99 procent zoonotických onemocnění, jako je vzteklina, bylo přenášeno ze psů na člověka, a dodal, že přístup One Health k ovládání a konečnému odstranění lidské vztekliny byl účelný."',
#   'score': '95',
#   'id': 321},
#  {'sentence': 'Original sentence: "Baloch\'s murder made international headlines and reignited calls for action against an epidemic of so-called "honour killings," in which a victim -- usually a woman -- is murdered for flouting patriarchal social codes." \n Translated sentence: "Balochova vražda učiněná mezinárodní titulky a vládnoucí výzvy k akci proti epidemii tzv. "čestných zabíjení", v níž oběť - obvykle žena - je zavražděna pro výmrtný patriarchální sociální kódy."',
#   'score': '85',
#   'id': 322},
#  {'sentence': 'Original sentence: "It had a reputation of being an underdog, but every season is different." \n Translated sentence: "Měl jsem pověst, že je podpún, ale každá sezóna je jiná."',
#   'score': '85',
#   'id': 323},
#  {'sentence': 'Original sentence: "A more discerning market for initial public offerings continued to punish Peloton Interactive Inc PTON.O on Friday, a day after it began trading, as shares of the fitness startup fell 4% to $24.74. The company is now trading 15% below its Wednesday IPO price." \n Translated sentence: "Ještě náročnější trh pro počáteční veřejné nabídky nadále potrestat Peloton Interactive Inc PTON.O v pátek, den poté, co začal obchodovat, jako akcie fitness startup padl 4% na $24.74. Společnost nyní obchoduje s 15 % pod středečním IPO cenou."',
#   'score': '92',
#   'id': 324},
#  {'sentence': 'Original sentence: "Saudi Arabia To Offer Tourist Visas For First Time, Abolish Abaya Rule" \n Translated sentence: "Saúdská Arábie nabízet turistická víza poprvé, zrušit Abaya pravidlo"',
#   'score': '92',
#   'id': 325},
#  {'sentence': 'Original sentence: "Viola Davis is feeling the pressure of playing Michelle Obama." \n Translated sentence: "Viola Davisová cítí tlak, že hraje Michelle Obamovou."',
#   'score': '92',
#   'id': 326},
#  {'sentence': 'Original sentence: "The White House released an unclassified version of that transcript of the call on Wednesday. The memo, which does not reflect a "verbatim transcript" but is based on "notes and recollections" of those memorializing the call, shows Trump seeking assistance in investigating the Bidens." \n Translated sentence: "Bílý dům ve středu zveřejnil nezařazenou verzi tohoto přepisu hovoru. Memorandum, které neodráží „doslovný přepis“, ale je založeno na „poznámkách a vzpomínkách“ těch, kteří zpopularizují hovor, ukazuje, že Trump hledá pomoc při vyšetřování Bidensových."',
#   'score': '92',
#   'id': 327},
#  {'sentence': 'Original sentence: ""Education workers have been under attack for decades," he continued. "We are finally standing up and fighting back. It\'s one thing to see classism and the squeezing of the middle class in the corporate world as executives see their relatively obscene pay continue to go up at rates above inflation. But for the same thing to be happening in education is not something workers will continue to tolerate."" \n Translated sentence: "„Zaměstnanci ve školství jsou pod útokem už desítky let,“ pokračoval. „Konečně stojíme a bráníme se. Jedna věc je vidět klasicismus a ždímání střední třídy v korporátním světě, když vedoucí pracovníci vidí, že jejich relativně obscénní platy dál rostou tempem nad inflací. Ale aby se totéž dělo ve školství, to není něco, co budou dělníci dál tolerovat.“"',
#   'score': '95',
#   'id': 328},
#  {'sentence': 'Original sentence: "He is now facing 10 counts of murder in Canada and 16 counts of attempted murder following the attack on April 23, 2018." \n Translated sentence: "V současnosti čelí 10 útokům v Kanadě a 16 pokusům o vraždu po útoku 23. dubna 2018."',
#   'score': '85',
#   'id': 329},
#  {'sentence': 'Original sentence: "The first two steps involve shining a torch at the trespassing elephant and sounding a horn." \n Translated sentence: "První dva kroky zahrnují zářící pochodeň při tvarování slona a znějící klakson."',
#   'score': '60',
#   'id': 330},
#  {'sentence': 'Original sentence: "Military Sees Frustrating Trend As Suicides Spike" \n Translated sentence: "Armáda vidí frustrující trend jako sebevraždy Spike"',
#   'score': '60',
#   'id': 331},
#  {'sentence': 'Original sentence: "She added that having Meghan present \'didn\'t feel hierarchical\', as it was \'women gathered together and a talk about the struggles we have, as well as the things we need to do to move forward and grow and change our societies\'." \n Translated sentence: "Dodala, že přítomnost Meghan „necítila se hierarchicky“, protože to bylo „ženy shromážděné a mluvily o bojích, které máme, stejně jako o věcech, které musíme udělat, abychom se posunuli kupředu a rostli a změnili naše společnosti“."',
#   'score': '92',
#   'id': 332},
#  {'sentence': 'Original sentence: "As Chairman of Midway Broadcasting Corporation, she joined an elite list of America\'s female broadcast owners after purchasing the company\'s controlling interest in 1999. Midway Broadcasting Corporation is a best-in-class female and family-owned media boutique whose properties include radio and interactive platforms." \n Translated sentence: "Jako předsedkyně Midway Broadcasting Corporation se po koupi kontrolního podílu v roce 1999 zařadila na elitní seznam amerických majitelů televizního vysílání. Midway Broadcasting Corporation je nejlepší mediální butik ve své třídě, který vlastní ženy a rodiny a jehož vlastnosti zahrnují rádio a interaktivní platformy."',
#   'score': '85',
#   'id': 333},
#  {'sentence': 'Original sentence: "US deaths could result in Scottish ban on vaping and e-cigarette ads" \n Translated sentence: "Americká úmrtí by mohla vyústit ve skotský zákaz štěpení a reklam na elektronické cigarety"',
#   'score': '85',
#   'id': 334},
#  {'sentence': 'Original sentence: "West Bengal government has plans to set up a museum at the north Kolkata house of 19th century social reformer Ishwar Chandra Vidyasagar where he had spent the last few years of his life, state minister Partha Chatterjee said." \n Translated sentence: "Vláda Západního Bengálska plánuje zřídit muzeum v severním Kolkatě v domě sociální reformátorky Ishwar Chandra Vidyasagar z 19. století, kde strávil několik posledních let svého života, řekla ministryně zahraničí Partha Chatterjee."',
#   'score': '85',
#   'id': 335},
#  {'sentence': 'Original sentence: "Jason Kenny, the defending champion from London, shone again with an excellent performance." \n Translated sentence: "Jason Kenny, obránce mistr z Londýna, opět zářil s vynikajícím výkonem."',
#   'score': '95',
#   'id': 336},
#  {'sentence': 'Original sentence: "Mosul, Iraq\'s second-largest city, remains under the control of the Islamic State." \n Translated sentence: "Mosul, druhé největší město Iráku, zůstává pod kontrolou Islámského státu."',
#   'score': '95',
#   'id': 337},
#  {'sentence': 'Original sentence: "Nancy then gave birth to a female named Astrid in 2013, with Stella being the third female calf born at the park in its 49-year history." \n Translated sentence: "Nancy pak v roce 2013 porodila samici jménem Astrid, přičemž Stella byla třetím mládětem narozeným v parku v jeho 49leté historii."',
#   'score': '95',
#   'id': 338},
#  {'sentence': 'Original sentence: "During a conversation with the female tech founders Meghan, who has campaigned vigorously for the empowerment of young women and girls, said she hopes to do the same for young men." \n Translated sentence: "Během rozhovoru se zakladatelkami technologie Meghan, která se energicky zasazuje o posílení postavení mladých žen a dívek, prohlásila, že doufá, že totéž učiní i pro mladé muže."',
#   'score': '95',
#   'id': 339},
#  {'sentence': 'Original sentence: "Each one of those brands will stand for something quite different in their own communities, and our staff will work with customers under those brands." \n Translated sentence: "Každá z těch značek bude stát za něčím úplně jiným ve vlastních obcích a naši zaměstnanci budou pracovat se zákazníky pod těmi značkami."',
#   'score': '95',
#   'id': 340},
#  {'sentence': 'Original sentence: ""It is imperative that the animal sector is adequately resourced to prevent transmission of rabies in dogs as a protective measure against the disease," he added." \n Translated sentence: "„Je nezbytně nutné, aby odvětví živočišné výroby mělo dostatečné zdroje, aby se zabránilo přenosu vztekliny u psů jako ochrannému opatření proti nákaze,“ dodal."',
#   'score': '95',
#   'id': 341},
#  {'sentence': 'Original sentence: "She and Karen Orvis, director of the suicide prevention office, said recognizing service members who may be struggling or at risk of taking their own lives is very difficult, and that sometimes suicide is a sudden, impulsive decision with little warning. They said it\'s difficult to identify reasons for suicide because there are so many stresses that could contribute." \n Translated sentence: "Spolu s Karen Orvisovou, ředitelkou úřadu pro prevenci sebevražd, uvedla, že rozpoznat příslušníky služby, kteří se mohou potýkat s problémy nebo jim hrozí, že si vezmou život, je velmi obtížné a že někdy je sebevražda náhlé, impulzivní rozhodnutí bez varování. Říkali, že je těžké určit důvody sebevraždy, protože je tu tolik stresů, které by mohly přispět."',
#   'score': '95',
#   'id': 342},
#  {'sentence': 'Original sentence: "The New Orleans Police Department opened their investigation into the tweet and in a police report Thursday revealed a twist in the story: The homophobic slur was allegedly sent from Dunlap\'s personal cellphone." \n Translated sentence: "Neworleanská policie zahájila vyšetřování tweetu a v policejní zprávě ve čtvrtek odhalila zvrat v příběhu: homofobní nadávka byla údajně odeslána z Dunlapova osobního mobilu."',
#   'score': '96',
#   'id': 343},
#  {'sentence': 'Original sentence: "We started the next set well with a changed defence strategy, we served well and dominated the court." \n Translated sentence: "Začali jsme dobře s novou obrannou strategií, dobře jsme si zasloužili a dominuli jsme soudu."',
#   'score': '85',
#   'id': 344},
#  {'sentence': 'Original sentence: "His sample swab showed a luminometer count of over 4000 units." \n Translated sentence: "Jeho vzorový výkyv ukázal jako luminometr více než 4000 jednotek."',
#   'score': '85',
#   'id': 345},
#  {'sentence': 'Original sentence: "It\'s unclear just how deeply such collective action may take root this fall, but it certainly would be fitting if the general strike returned to the Northwest in 2019. And from there we can only hope that its spirit will spread even further, into the heart of Midwestern farming, Southern manufacturing, Texan oil fields, Appalachian coal mines, Northeastern construction, the Silicon Valley tech giants, and everywhere in between. Lord knows that something\'s gotta give." \n Translated sentence: "Není jasné, jak hluboce takové kolektivní akce může zakořenit tento pád, ale určitě by bylo vhodné, pokud obecný stávka se vrátila na severozápad v roce 2019. A odtud můžeme jen doufat, že jeho duch se bude šířit ještě dále, do srdce Středozápadního zemědělství, Jižní výroby, Texan olejová pole, Appalachian uhelné doly, Severovýchodní konstrukce, Silicon Valley tech obry, a všude mezi. Pán ví, že něco se musí dát."',
#   'score': '85',
#   'id': 346},
#  {'sentence': 'Original sentence: "Brexit can get plenty more toxic from here." \n Translated sentence: "Brexit může být mnohem toxičtější."',
#   'score': '85',
#   'id': 347},
#  {'sentence': 'Original sentence: "Do they want to push back against those who are damaging the reputation of their services?" \n Translated sentence: "Chtějí zatlačit proti těm, kteří ničení jejich služeb zničí?"',
#   'score': '85',
#   'id': 348},
#  {'sentence': 'Original sentence: "The initiative is aimed at reducing new HIV/Aids infections by 2020." \n Translated sentence: "Iniciativa je zaměřena na snížení nových infekcí HIV/Aids do roku 2020."',
#   'score': '95',
#   'id': 349},
#  {'sentence': 'Original sentence: "A judge sentencing a teenager for a violent attack on a love rival appeared to show just as much concern about his choice of drink in the lead up to it." \n Translated sentence: "Soudce, který odsoudil teenagera za násilný útok na rivala v lásce, zřejmě projevil stejnou starost o jeho výběr pití, které vedlo až k němu."',
#   'score': '92',
#   'id': 350},
#  {'sentence': 'Original sentence: "Hun Sen\'s government seems unnerved by the planned return of opposition politicians, though the effort appears to be a quixotic one, with Sam Rainsy calling on Cambodian workers in Thailand to accompany him home in massive numbers." \n Translated sentence: "Vláda Hun Sen se zdá být nezasloužena plánovaným návratem opozičních politiků, i když úsilí se zdá být quixotický, se Samem Rainsy vyzývá k Kambodžským pracovníkům v Thajsku, aby ho doprovázel domů v masivních číslech."',
#   'score': '85',
#   'id': 351},
#  {'sentence': 'Original sentence: "Mohandas Karamchand "Mahatma" Gandhi, who was born on Oct. 2, 1869, left a worldwide legacy with his focus on ethics, nonviolence, tolerance and social justice. He had a profound impact on two of the most important mass mobilizations in the United States." \n Translated sentence: "Mohandas Karamchand „Mahátma“ Gándhí, který se narodil 2. října 1869, zanechal celosvětové dědictví se zaměřením na etiku, nenásilí, toleranci a sociální spravedlnost. Měl hluboký dopad na dvě z nejdůležitějších masových mobilizací ve Spojených státech."',
#   'score': '95',
#   'id': 352},
#  {'sentence': 'Original sentence: "We do not have a multinational investor with deep pockets backing us. We are two regular guys - one who had a great idea and another who jumped on the bandwagon with additional suggestions and ideas." \n Translated sentence: "Nemáme ani mezinárodní investoři s hlubokými kapsami, jsme dva obyčejní lidé - jeden, který měl skvělý nápad a další, kdo skočil na ten bankomat s dalšími návrhy a nápady."',
#   'score': '65',
#   'id': 353},
#  {'sentence': 'Original sentence: "As Chairman of Midway Broadcasting Corporation, she joined an elite list of America\'s female broadcast owners after purchasing the company\'s controlling interest in 1999. Midway Broadcasting Corporation is a best-in-class female and family-owned media boutique whose properties include radio and interactive platforms." \n Translated sentence: "Jako předsedkyně Midway Broadcasting Corporation se po koupi kontrolního podílu společnosti v roce 1999 připojila k elitnímu seznamu amerických majitelek vysílání. Midway Broadcasting Corporation je nejlepší mediální butik ve své třídě ve své třídě, jehož vlastnosti zahrnují rozhlasové a interaktivní platformy ."',
#   'score': '85',
#   'id': 354},
#  {'sentence': 'Original sentence: "Woman STRIPS TO NOTHING in Walmart to prove she didn\'t steal" \n Translated sentence: "Žena STRIPS TO NIC ve Walmartu, aby dokázala, že nekradla"',
#   'score': '85',
#   'id': 355},
#  {'sentence': 'Original sentence: "U.S. Soldiers talk after a routine inspection of a Patriot missile battery at a Turkish military base in Gaziantep, Turkey." \n Translated sentence: "USA. Vojáci mluví po rutinní kontrole patriotové raketové baterie v turecké vojenské základně v Gaziantep, Turecku."',
#   'score': '96',
#   'id': 356},
#  {'sentence': 'Original sentence: "As Chairman of Midway Broadcasting Corporation, she joined an elite list of America\'s female broadcast owners after purchasing the company\'s controlling interest in 1999. Midway Broadcasting Corporation is a best-in-class female and family-owned media boutique whose properties include radio and interactive platforms." \n Translated sentence: "Jako předsedkyně Midway Broadcasting Corporation se připojila k elitnímu seznamu amerických vlastníků ženského vysílání poté, co v roce 1999 zakoupila kontrolní podíl společnosti. Midway Broadcasting Corporation je best-in-class female and family-owned media boutique, jehož vlastnosti zahrnují rozhlasové a interaktivní platformy."',
#   'score': '85',
#   'id': 357},
#  {'sentence': 'Original sentence: "The company offered an explanation: The lens was meant as homage to anime characters, not as a caricature of Asian people." \n Translated sentence: "Společnost mu nabídla vysvětlení: čočky byly určeny jako podomácku vyhnanství, ne jako karikatura asijských lidí."',
#   'score': '40',
#   'id': 358},
#  {'sentence': 'Original sentence: "Rock legends The Who are on a major US tour. In Houston, Texas, Roger Daltrey was forced to call off the concert less than halfway through. The 75-year-old told the disappointed audience: "I think I should quit while I\'m ahead." The band had performed eight songs already but promised to try and return for another show one day in the future. Watch the video of how it all unfolded on stage." \n Translated sentence: "Rockové legendy The Who jsou na velkém americkém turné. V Houstonu v Texasu byl Roger Daltrey nucen odvolat koncert méně než v polovině. 75-rok-starý řekl zklamané publikum: "Myslím, že bych měl skončit, když jsem napřed." Kapela už zahrála osm písní, ale slíbila, že se jednoho dne v budoucnu pokusí vrátit na další show. Podívejte se na video o tom, jak se to všechno rozvinulo na jevišti."',
#   'score': '95',
#   'id': 359},
#  {'sentence': 'Original sentence: "Using data and artificial intelligence to try and boost revenues is part of HSBC\'s broader push to squeeze more out of its large physical network and client data, a key priority for interim Chief Executive Noel Quinn." \n Translated sentence: "Využití dat a umělé inteligence k pokusu o zvýšení výnosů je součástí širšího úsilí HSBC o vytlačení většího množství dat z rozsáhlé fyzické sítě a klientských dat, což je pro prozatímního výkonného ředitele Noela Quinna klíčová priorita."',
#   'score': '92',
#   'id': 360},
#  {'sentence': 'Original sentence: "As the investigation into the fatal shooting continues, Alford said he wasn\'t giving up either." \n Translated sentence: "Vzhledem k tomu, vyšetřování smrtelné střelby pokračuje, Alford řekl, že se nevzdává."',
#   'score': '95',
#   'id': 361},
#  {'sentence': 'Original sentence: "Geomagnetic Storm in the Last days of September" \n Translated sentence: "Geomagnetická bouře v posledních dnech září"',
#   'score': '95',
#   'id': 362},
#  {'sentence': 'Original sentence: "Some of the first protests began in New Zealand, where Thunberg saidorganizers estimated 170,000 people marched across the country. There were also marches in cities in Italy, Finland, Nigeria, Austria and India, among other countries." \n Translated sentence: "Některé z prvních protestů začaly na Novém Zélandu, kde podle Thunberga podle odhadů organizátorů pochodovalo po celé zemi 170 tisíc lidí. Pochody se konaly mimo jiné i ve městech v Itálii, Finsku, Nigérii, Rakousku a Indii."',
#   'score': '95',
#   'id': 363},
#  {'sentence': 'Original sentence: "The Phnom Penh Municipal Court also warned that anyone who supported the plans of the Cambodia National Rescue Party to oust the government would also be risking a long prison term." \n Translated sentence: "Městský soud v Phnompenhu také varoval, že každý, kdo by podpořil plány Kambodžské národní záchranné strany na svržení vlády, by také riskoval dlouhodobé vězení."',
#   'score': '95',
#   'id': 364},
#  {'sentence': 'Original sentence: "Aspiring champions jump on a giant trampoline, shooting up to nearly 30 feet in the air, and are called upon to perform a series of tumbling moves (twists, pikes and somersaults) before eventually landing on their feet." \n Translated sentence: "Ve vzduchu se na obr skáče, a pak se po něm přihodí řada tukujících se pohybů (krutosti, keců a somersaultů), než přistane,"',
#   'score': '65',
#   'id': 365},
#  {'sentence': 'Original sentence: "The US may be the world\'s wealthiest nation, but it is also one where the super-rich thrive no matter what while the desperately poor often rely on GoFundMe to pay their medical bills. The economic inequality affects both wealth and incomes, with the latter being at an all-time high." \n Translated sentence: "USA jsou sice nejbohatším státem na světě, ale také zemí, kde se daří superbohatým bez ohledu na cokoli, zatímco zoufale chudí často spoléhají na GoFundMe, že jim zaplatí lékařské účty. Ekonomická nerovnost ovlivňuje bohatství i příjmy, přičemž příjmy jsou na historickém maximu."',
#   'score': '95',
#   'id': 366},
#  {'sentence': 'Original sentence: "The company is going after ad blockers on desktop however, because mobile ad blockers are not effective in Facebook\'s mobile apps for the social network and Instagram, a spokesperson said." \n Translated sentence: "Společnost se však chystá na rozmanitých bloků, protože mobilní inzeráty nejsou v mobilních apátech v mobilních apátech v mobilních apátech na sociální síti a Instagram, řekl mluvčí."',
#   'score': '20',
#   'id': 367},
#  {'sentence': 'Original sentence: "A statement from the Kremlin said that Mr Putin had "decreed to relieve Ivanov of his duties as head of the Russian presidential administration," but gave no reason." \n Translated sentence: "Prohlášení Kremlu řekl, že pan Putin prohlásil, že „nařídil Ivanovovi, aby se zbavoval jeho povinností ruské prezidentské vlády,“ ale bezdůvodně."',
#   'score': '85',
#   'id': 368},
# ...
#   'score': '85',
#   'id': 459},
#  {'sentence': 'Original sentence: "Included in the five praised students were Nicholas Gallagher and James Osbourne (both Life Sciences), Ferenc Kohsuke Ishikawa Gutai (Medicine), Caitlyn Scott (Anatomical Sciences) and Waco Yokoyama (Philosophy)." \n Translated sentence: "Mezi pět oceněných studentů byli zahrnuti Nicholas Gallagher a James Osbourne (oba vědy o životě), Ferenc Kohsuke Ishikawa Gutai (medicína), Caitlyn Scott (anatomické vědy) a Waco Yokoyama (filozofie)."',
#   'score': '95',
#   'id': 460},
#  {'sentence': 'Original sentence: "Scott Sheldrick, who graduated in Molecular Genetics, won the Europe award for Life Sciences, Chester Cornford studied MSc Mental Health Nursing and was awarded the Nursing, Midwifery & Allied Healthcare prize, whilst Lola Knibb won the Visual Arts award." \n Translated sentence: "Scott Sheldrick, který absolvoval obor Molekulární genetika, získal evropskou cenu za vědy o životě, Chester Cornford studoval obor MSc Mental Health Nursing a byl oceněn cenou Nursing, Midwifery & Allied Healthcare, zatímco Lola Knibb získala cenu Visual Arts."',
#   'score': '96',
#   'id': 461},
#  {'sentence': 'Original sentence: "One of them would be a special charge on halal food, i.e. mainly meat from animals slaughtered according to Islamic principles." \n Translated sentence: "Jeden z nich by byl zvláštní poplatek na halal jídlo, tedy hlavně maso ze zvířat poražených podle islámských zásad."',
#   'score': '95',
#   'id': 462},
#  {'sentence': 'Original sentence: ""Opening Saudi Arabia to international tourists is a historic moment for our country," tourism chief Ahmed al-Khateeb said in a statement." \n Translated sentence: "„Otevření Saúdské Arábie mezinárodním turistům je pro naši zemi historickým okamžikem,“ uvedl v prohlášení šéf cestovního ruchu Ahmed al-Khateeb."',
#   'score': '98',
#   'id': 463},
#  {'sentence': 'Original sentence: "The second set was great and the third was decided by serves." \n Translated sentence: "Druhá sada byla skvělá a o třetí se rozhodovala podle servítků."',
#   'score': '85',
#   'id': 464},
#  {'sentence': 'Original sentence: "During a conversation with the female tech founders Meghan, who has campaigned vigorously for the empowerment of young women and girls, said she hopes to do the same for young men." \n Translated sentence: "Během konverzace se zakladatelkou techniky Meghan, která razantně bojovala o posílení mladých žen a dívek, řekla, že doufá, že totéž udělá i pro mladé muže."',
#   'score': '95',
#   'id': 465},
#  {'sentence': 'Original sentence: "Some people who come to France as tourists, for example, may not be so aware of it." \n Translated sentence: "Někteří lidé, kteří se přidají do Francie jako turisté, možná si toho nevšimnou."',
#   'score': '85',
#   'id': 466},
#  {'sentence': 'Original sentence: "Its banishment would be poetic justice for his Taliban-like destruction of so many of England\'s cultural and religious artefacts carried out by his fanatical Puritan followers." \n Translated sentence: "Jeho vyhnanství by byla poetická spravedlnost pro jeho zničení, podobné mnoha kulturním a náboženským artefaktům Anglie, které provádějí jeho fanatičtí puritánští stoupenci."',
#   'score': '85',
#   'id': 467},
#  {'sentence': 'Original sentence: "Meghan Markle is determined to \'fulfil her heart\'s desires\' and not let her own needs \'fade away\' now she\'s a member of the Royal Family - and wants to be a role model for young boys as well as girls." \n Translated sentence: "Meghan Markle je odhodlaná ′′ naplnit přání svého srdce ′′ a nenechat své vlastní potřeby ′′ zmizet ′′ nyní je členkou Královské rodiny - a chce být vzorem pro mladé chlapce i dívky."',
#   'score': '95',
#   'id': 468},
#  {'sentence': 'Original sentence: ""I mean, I guess if you could tell me, I would appreciate it," she told reporters. "I mean, I have always been an Avenger in my heart. Maybe I\'m super strong. I don\'t know."" \n Translated sentence: "„Myslím, že kdybyste mi to mohla říct, ocenila bych to,“ řekla novinářům. „Vždycky jsem byl ve svém srdci Avenger. Možná jsem super silný. Já nevím.“"',
#   'score': '92',
#   'id': 469},
#  {'sentence': 'Original sentence: "Apparently he thinks the calendar is, too." \n Translated sentence: "Podle všeho si myslí i kalendář."',
#   'score': '60',
#   'id': 470},
#  {'sentence': 'Original sentence: "Meghan to \'fulfil her heart\'s desires\' and refuses let own needs \'fade away\' amid her royal duties" \n Translated sentence: "Meghan „plní své srdeční touhy“ a odmítne nechat vlastní potřeby „vypadnout“ uprostřed svých královských povinností"',
#   'score': '95',
#   'id': 471},
#  {'sentence': 'Original sentence: "This seems to confirm the rule of thumb that traders should not bet against the interests of central banks, which have so far always achieved what they set out to do." \n Translated sentence: "Zdá se, že to potvrzuje pravidlo palců, že obchodníci by neměli sázet proti zájmům centrálních bank, které tak daleko dosáhly, co se jim podařilo udělat."',
#   'score': '95',
#   'id': 472},
#  {'sentence': 'Original sentence: "At the start of the campaign, Cooper and captain Lastimosa crash on an alien planet Typhon, which is inhabited by enemy troops." \n Translated sentence: "Na začátku kampaně, Coopera a kapitánovu havarování, havarovali na mimozemské planetě Typhon, který je obydlený nepřátelskými vojáky."',
#   'score': '85',
#   'id': 473},
#  {'sentence': 'Original sentence: "Meanwhile, Trump lawyer Jay Sekulow downplayed the importance of the record-keeping details." \n Translated sentence: "Trumpův právník Jay Sekulow mezitím význam záznamů bagatelizoval."',
#   'score': '92',
#   'id': 474},
#  {'sentence': 'Original sentence: "President Donald Trump slammed Iran\'s alleged role in the attacks on Saudi oil facilities, telling world leaders at the U.N. General Assembly on Tuesday that they should pressure Tehran into diplomatic talks." \n Translated sentence: "Prezident Donald Trump udeřil údajnou íránskou roli v útocích na saúdská ropná zařízení a v úterý řekl světovým lídrům na Valném shromáždění OSN, že by měli tlačit Teherán k diplomatickým rozhovorům."',
#   'score': '95',
#   'id': 475},
#  {'sentence': 'Original sentence: ""The relentless search for better answers continues to be at the core of everything we do," Google writes on its Our Story page. "Today, with more than 60,000 employees in 50 different countries, Google makes hundreds of products used by billions of people across the globe, from YouTube and Android to Smartbox and, of course, Google Search. Although we\'ve ditched the Lego servers and added just a few more company dogs, our passion for building technology for everyone has stayed with us - from the dorm room, to the garage, and to this very day." \n Translated sentence: "„Neúprosné hledání lepších odpovědí je nadále jádrem všeho, co děláme,“ píše Google na své stránce Náš příběh. „Dnes, s více než 60 tisíci zaměstnanci v 50 různých zemích, vyrábí Google stovky produktů, které používají miliardy lidí po celém světě, od YouTube a Androidu po Smartbox a samozřejmě Google Search. I když jsme se vykašlali na Lego servery a přidali jen pár dalších firemních psů, naše vášeň pro stavění technologií pro všechny nám zůstala – od pokoje na koleji, přes garáž až dodnes."',
#   'score': '95',
#   'id': 476},
#  {'sentence': 'Original sentence: ""They are constantly berating their father for allowing it to happen and Beatrice in particular has been imploring Prince Andrew to see that their mother is not treated as an outcast."" \n Translated sentence: "„Neustále spílají svému otci, že to dovolil, a Beatrice zejména prosí prince Andrewa, aby dohlédl na to, aby s jejich matkou nebylo zacházeno jako s vyvrhelem.“"',
#   'score': '92',
#   'id': 477},
#  {'sentence': 'Original sentence: "Mr. Poroshenko\'s eagerness to win over Mr. Trump and his growing fears that political rivals would thwart his re-election opened the way for Mr. Giuliani to press Ukraine\'s prosecutor general, Yuri Lutsenko, who has since been fired, to help Mr. Trump\'s own re-election by investigating Joe Biden and his son." \n Translated sentence: "Porošenkova dychtivost vyhrát nad Trumpem a jeho rostoucí obavy, že političtí rivalové zmaří jeho znovuzvolení, otevřely cestu k tomu, aby giuliani tlačil na ukrajinského generálního prokurátora Jurije Lutsenka, který byl od té doby propuštěn, aby pomohl trumpovu znovuzvolení vyšetřováním Joe Bidena a jeho syna."',
#   'score': '95',
#   'id': 478},
#  {'sentence': 'Original sentence: "The band left the stage, originally suggesting they would try to work out the rest of the set without Roger." \n Translated sentence: "Kapela odešla z pódia a původně navrhovala, že se pokusí zbytek setu zvládnout bez Rogera."',
#   'score': '92',
#   'id': 479},
#  {'sentence': 'Original sentence: "Children around the world launched another wave of school strikes demanding action on climate change Friday, in their first major action since the issue topped world leader\'s agenda at the United Nations this week." \n Translated sentence: "Děti po celém světě zahájily v pátek další vlnu školních stávek požadujících opatření proti klimatickým změnám, což je jejich první velká akce od chvíle, kdy se toto téma tento týden dostalo na první místo agendy světového lídra v Organizaci spojených národů."',
#   'score': '95',
#   'id': 480},
#  {'sentence': 'Original sentence: "The Duchess of Sussex appeared in archive Suits footage during the finale\'s montage." \n Translated sentence: "Vévodkyně ze Sussexu se objevila v archivních záběrech během závěrečné montáže."',
#   'score': '95',
#   'id': 481},
#  {'sentence': 'Original sentence: "The dog was brought to a local animal shelter and his rescuer has since been hailed as a hero." \n Translated sentence: "Pes byl převezen do místního útulku pro zvířata a jeho zachránce je od té doby oslavován jako hrdina."',
#   'score': '96',
#   'id': 482},
#  {'sentence': 'Original sentence: "The motorway operators know that it is there illegally, but claim there is nothing they can do about it." \n Translated sentence: "Provozovatelé dálnic vědí, že tam je nelegálně, ale tvrdí, že s tím nic nenadělají."',
#   'score': '95',
#   'id': 483},
#  {'sentence': 'Original sentence: ""Now that we already did it, I will tell you," Korsh replied." \n Translated sentence: ""Teď, když už jsme to udělali, řeknu vám to," odpověděl Korsh."',
#   'score': '95',
#   'id': 484},
#  {'sentence': 'Original sentence: "Antonio Brown says he\'s not quite ready for retirement" \n Translated sentence: "Antonio Brown říká, že není úplně připravený na důchod"',
#   'score': '95',
#   'id': 485},
#  {'sentence': 'Original sentence: "She is a supermodel, in the purest sense of the word." \n Translated sentence: "Je supermodelkou, v tom pravém smyslu slova."',
#   'score': '95',
#   'id': 486},
#  {'sentence': 'Original sentence: "As never before or since, home economists - among them Louise Stanley, chief of the federal Bureau of Home Economics from 1923 to 1943 - drove the country\'s eating habits." \n Translated sentence: "Jako nikdy předtím, nebo od té doby, domácí ekonomové - mezi nimi Louise Stanleyovou, hlavní šéf federálního úřadu ekonomie z roku 1923 až 1943 - dohnal potraviny v zemi."',
#   'score': '85',
#   'id': 487},
#  {'sentence': 'Original sentence: "Junior doctors and medical students voted in July to reject a contract deal agreed with the BMA." \n Translated sentence: "V červenci hlasovali mladší lékaři a studenti medicíny, aby odmítli smlouvu o smlouvě dohodnuté s Bmi."',
#   'score': '85',
#   'id': 488},
#  {'sentence': 'Original sentence: "The Duchess of Sussex, 38, reportedly made the remarks during an event for inspiring female entrepreneurs at Woodstock Exchange in Cape Town earlier this week during her tour of South Africa with husband Prince Harry." \n Translated sentence: "Osmatřicetiletá vévodkyně ze Sussexu to údajně pronesla během akce pro inspiraci podnikatelek na Woodstock Exchange v Kapském Městě začátkem tohoto týdne během své cesty po Jižní Africe s manželem princem Harrym."',
#   'score': '95',
#   'id': 489},
#  {'sentence': 'Original sentence: "Not least it was also important to safeguard the quality of execution." \n Translated sentence: "Bylo také důležité, aby byla také důležitá, aby byla zajištěna kvalita popravy."',
#   'score': '35',
#   'id': 490},
#  {'sentence': 'Original sentence: "The U.S. Attorney\'s Office and the FBI said a federal review of the 2018 shooting of 22-year-old Stephon Clark found "insufficient evidence" to pursue charges against Officers Terrance Mercadal and Jared Robinet. Both will be returned to active duty." \n Translated sentence: "Úřad státního návladního a FBI uvedly, že federální přezkum střelby 22letého Stephona Clarka v roce 2018 našel "nedostatečné důkazy", aby mohli vznést obvinění proti důstojníkům Terranci Mercadalovi a Jaredu Robinetovi. Oba budou vráceni do aktivní služby."',
#   'score': '95',
#   'id': 491},
#  {'sentence': 'Original sentence: "Royal Bank of Scotland will be used with Scottish customers, but will not be initialised." \n Translated sentence: "Skotská královská banka bude používat skotské zákazníky, ale nebudou se s ním muset zabývat."',
#   'score': '65',
#   'id': 492},
#  {'sentence': 'Original sentence: ""Now that we already did it, I will tell you," Korsh replied." \n Translated sentence: "„Teď, když už jsme to udělali, vám to povím,“ odpověděl Korš."',
#   'score': '95',
#   'id': 493},
#  {'sentence': 'Original sentence: "Antonio Brown has indicated he\'s not retiring from the NFL, only a few days after announcing he was done with the league in a Twitter rant." \n Translated sentence: "Antonio Brown naznačil, že neodchází z NFL, jen pár dní poté, co oznámil, že s ligou na Twitteru skončil."',
#   'score': '95',
#   'id': 494},
#  {'sentence': 'Original sentence: "Police public relations chief Tse Chun-chung said 207 high school and university students were detained this month alone despite the resumption of classes after the summer holiday, compared to 257 over the June-August period." \n Translated sentence: "Policejní ředitel pro styk s veřejností Tse Chun-chung uvedl, že jen tento měsíc bylo zadrženo 207 studentů středních a vysokých škol, a to i přes obnovení vyučování po letních prázdninách, oproti 257 v období červen-srpen."',
#   'score': '95',
#   'id': 495},
#  {'sentence': 'Original sentence: "House Speaker Nancy Pelosi, D-Calif., who was prompted by Ukraine developments this week to announce a formal impeachment inquiry into the president, called the move a "cover-up" and said it would be part of the impeachment inquiry." \n Translated sentence: "Předsedkyně Sněmovny reprezentantů Nancy Pelosiová, D-Calif., kterou vývoj na Ukrajině tento týden přiměl k oznámení formálního vyšetřování obžaloby prezidenta, označila tento krok za „zastírací manévr“ a řekla, že bude součástí vyšetřování obžaloby."',
#   'score': '95',
#   'id': 496},
#  {'sentence': 'Original sentence: "The indictment of seven people will hardly eradicate a well-known Prague vice, which appears to be much bigger." \n Translated sentence: "Obžaloba sedmi lidí téměř vymýtit známý pražský nešvar, který se zdá být mnohem větší."',
#   'score': '92',
#   'id': 497},
#  {'sentence': 'Original sentence: "The sender will be charged a few percentage points extra for arranging the contact between the two sides." \n Translated sentence: "Odesílatel (i) bude účtován/a/o pár procentních bodů navíc za zprostředkování kontaktu mezi oběma stranami."',
#   'score': '95',
#   'id': 498},
#  {'sentence': 'Original sentence: "Angela Rochelle Liner, Stefanie R. Ellis and Ellis\' daughter Maleah were shot on June 12 while the car was parked in a driveway, authorities said." \n Translated sentence: "Angela Rochelle Linerová, Stefanie R. Ellis a Ellis \'dcera Maleah byli zastřeleni 12. června, když auto zaparkovali na příjezdové cestě, řekli mi to."',
#   'score': '85',
#   'id': 499}]

# %%
def recover_all_files(path: str):
    files_content = []

    for filename in os.listdir(path):
        with open(f'{path}/{filename}') as infile:
            file_content = json.load(infile)
            files_content += file_content
    return pd.DataFrame(files_content).sort_values(by='id').reset_index(drop=True)

# %%
df_llama = recover_all_files('../data/llama_3')

# %%
df_llama
# Out:
#                                                sentence score    id
# 0     Original sentence: "Police said in a statement...    92     0
# 1     Original sentence: "Trump will likely veto the...    95     1
# 2     Original sentence: "The man arrived at work ab...    85     2
# 3     Original sentence: "Are hopes for a nuclear-fr...    95     3
# 4     Original sentence: "The California attorney ge...    92     4
# ...                                                 ...   ...   ...
# 2392  Original sentence: "Wayalela amagosa ukuba aye...    85  2395
# 2393  Original sentence: "Ulimo lokuphila lulula, ol...    95  2396
# 2394  Original sentence: "UMlawuli wezoTshutshiso lo...    95  2397
# 2395  Original sentence: "Ukuphumla phezu kweentaba ...    95  2398
# 2396  Original sentence: "Izithethe ezincinci zidiba...    92  2399
#
# [2397 rows x 3 columns]

# %%
df_llama.score.unique()
# Out:
# array(['92', '95', '85', '65', '90', '75', '60', '80', '96', '40', '20',
#        '45', '98', '70', '35', '78', '87', '68', '72', '0', '62', '99',
#        '30', '34', '10', '82', '97'], dtype=object)

# %%
for i in range(2400):
    if i not in df_llama.id.to_list():
        print(i)
# Out:
# 10
# 16
# 24

# %%
last_idx = 1500
max_rows = 2401
outfile = f'../data/llama_3/missing_starting_row.json'

with open(outfile, 'w') as output_file:
    output_file.write('[')
    for i in [10,16,24]:
        try:
            sample = input_data[i]
            chat_completion = client.chat.completions.create(
                messages=input_data[i],
                model="llama3-70b-8192",
                temperature=0.5,
                max_tokens=1024,
                top_p=1,
                stop=None,
                stream=False,
            )
            answer = chat_completion.choices[0].message.content

            output_sample = {'sentence': sample[-1]['content'],'score': answer, 'id':i}
            
            output_file.write(json.dumps(output_sample))

            if i != (max_rows-1):
                output_file.write(',')
        except:
            print('next start by:')
            print(i + 1)
            break
    output_file.write(']')
